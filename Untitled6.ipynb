# %% [markdown]
# <a href="https://colab.research.google.com/github/prashanth741/AIML/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {'Name': ['prashanth', 'hari', 'koushik', 'shiva'],
    'Age': [25, 30, 35, 40],
    'Height (cm)': [160, 175, 180, 165],
    'Weight (kg)': [55, 70, 80, 60]}

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.bar(df['Name'], df['Age'], color='pink')
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Bar Graph of Ages')
plt.grid(axis='y')

plt.subplot(1, 2, 2)

sns.scatterplot(data=df, x='Height (cm)', y='Weight (kg)', hue='Name', palette='viridis', s=100)
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Scatter Plot of Height vs Weight')

plt.tight_layout()
plt.show()
